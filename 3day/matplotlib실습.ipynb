# %%
# %matplotlib nbagg

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot?

# %%
sr = pd.Series(np.random.randn(10).cumsum(),
              index=np.arange(0,100,10)) 
sr
# Out:
# 0    -1.483744
# 10   -3.572239
# 20   -3.869588
# 30   -3.623822
# 40   -4.863006
# 50   -4.778184
# 60   -5.794651
# 70   -3.868119
# 80   -2.562034
# 90   -2.454342
# dtype: float64

# %%
sr.plot()
plt.savefig('figure.svg')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.savefig?

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0  -1.213111 -0.039595  1.016475  0.460794
# 10  0.949833  0.358973  2.719787  2.451151
# 20  1.928752  1.101834  2.644890  2.340733
# 30  1.361827  0.649235  1.154013  1.694204
# 40 -0.279797  0.676606  1.109696  2.616010
# 50 -1.088698  0.164906 -0.095154  2.787146
# 60 -1.176799 -0.474687 -1.257391  3.090391
# 70 -0.287723 -0.329762  0.343407  4.426608
# 80 -0.317131  0.822840  1.343981  5.215807
# 90 -1.695030  0.477929 -0.332747  4.256975

# %%
df.plot()
plt.savefig('f2.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(df)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0xb409240>,
#  <matplotlib.lines.Line2D at 0xb409390>,
#  <matplotlib.lines.Line2D at 0xb4094e0>,
#  <matplotlib.lines.Line2D at 0xb409630>]

# %%
df["B"].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr2 = pd.Series(np.random.rand(15), index=list("abcdefghijklmno"))

# %%
sr2
# Out:
# a    0.212117
# b    0.071314
# c    0.165251
# d    0.808153
# e    0.703672
# f    0.139788
# g    0.167695
# h    0.201206
# i    0.881410
# j    0.129425
# k    0.838620
# l    0.457007
# m    0.547878
# n    0.158337
# o    0.579478
# dtype: float64

# %%
sr2.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">
