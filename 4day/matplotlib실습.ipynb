# %%
# %matplotlib nbagg

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot?

# %%
sr = pd.Series(np.random.randn(10).cumsum(),
              index=np.arange(0,100,10)) 
sr
# Out:
# 0    -1.297644
# 10   -2.551210
# 20   -2.695221
# 30   -2.491657
# 40   -1.581926
# 50   -0.469984
# 60   -0.464803
# 70    0.396111
# 80    2.614702
# 90    2.818940
# dtype: float64

# %%
sr.plot()
plt.savefig('figure.svg')

# %%
plt.savefig?

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0  -0.047439 -1.850141  1.327090  0.382087
# 10  0.003911 -0.134606  0.770626 -0.930420
# 20 -0.783713  0.299355  0.819439 -1.135520
# 30 -1.532259  0.547867  0.994635 -3.292743
# 40 -0.982200  1.398848  0.575799 -3.388883
# 50 -0.445867  3.385999  1.005515 -1.486590
# 60 -0.653884  4.219936  1.543303 -2.058746
# 70 -1.010969  4.854956  2.546851 -2.525518
# 80 -2.251607  3.575677  0.992981 -1.624439
# 90 -2.293038  2.987261  2.730558 -3.405553

# %%
df.plot()
plt.savefig('f2.png')

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0xac174a8>,
#  <matplotlib.lines.Line2D at 0xac176a0>,
#  <matplotlib.lines.Line2D at 0xac177f0>,
#  <matplotlib.lines.Line2D at 0xac17940>]

# %%
df["B"].plot()

# %%
sr2 = pd.Series(np.random.rand(15), index=list("abcdefghijklmno"))

# %%
sr2
# Out:
# a    0.835024
# b    0.647161
# c    0.528919
# d    0.277074
# e    0.631202
# f    0.219677
# g    0.874929
# h    0.872869
# i    0.864447
# j    0.482363
# k    0.308062
# l    0.050302
# m    0.962519
# n    0.490378
# o    0.722307
# dtype: float64

# %%
sr2.plot(kind='bar')

# %%
sr2
# Out:
# a    0.835024
# b    0.647161
# c    0.528919
# d    0.277074
# e    0.631202
# f    0.219677
# g    0.874929
# h    0.872869
# i    0.864447
# j    0.482363
# k    0.308062
# l    0.050302
# m    0.962519
# n    0.490378
# o    0.722307
# dtype: float64

# %%
sr2.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Number"))

# %%
df2
# Out:
# Number         A         B         C         D
# one     0.340652  0.762100  0.701879  0.756221
# two     0.032806  0.627848  0.560100  0.065671
# three   0.305128  0.739692  0.485063  0.464022
# four    0.005074  0.384428  0.297912  0.802888
# five    0.423431  0.362534  0.234687  0.075721
# six     0.788782  0.857731  0.468644  0.909214

# %%
df2.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %%
df2.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %%
df2.plot(kind='barh', stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
sr3 = pd.Series(np.random.normal(0, 1, size=200))

# %%
sr3
# Out:
# 0     -1.322721
# 1      0.196223
# 2      2.120113
# 3      0.622091
# 4      0.674476
# 5      1.359785
# 6     -1.463898
# 7     -0.269832
# 8      0.454879
# 9      0.097658
# 10     0.298902
# 11     0.021904
# 12     0.852406
# 13    -0.036573
# 14     0.301602
# 15     0.079039
# 16    -2.047351
# 17    -1.203600
# 18     0.991602
# 19    -0.371628
# 20    -1.535578
# 21     0.857624
# 22     1.352437
# 23    -0.867166
# 24    -1.286552
# 25     0.070369
# 26     1.298491
# 27     1.359900
# 28     1.584413
# 29    -2.367503
#          ...
# 170    0.798833
# 171   -0.035403
# 172   -0.607732
# 173   -1.662261
# 174    0.676458
# 175    0.942812
# 176   -2.238925
# 177   -0.399309
# 178    0.176144
# 179    1.025504
# 180    1.934433
# 181    0.140709
# 182   -0.626774
# 183   -1.107163
# 184    0.436946
# 185    0.639410
# 186    1.424919
# 187   -1.124105
# 188   -0.926140
# 189    0.780299
# 190   -0.527449
# 191    2.236789
# 192    0.925245
# 193   -0.000539
# 194   -0.066911
# 195   -0.683435
# 196   -1.414519
# 197   -0.870333
# 198   -1.631339
# 199    0.080321
# Length: 200, dtype: float64

# %%
sr3.hist()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
sr3.hist(bins=50)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
sr3.hist(bins=50, normed=True)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
sr3.hist(bins=100, normed=True)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))
X = np.concatenate((x1, x2), axis=1)

# %%
X
# Out:
# array([[  1.1393137 ,   2.00921052],
#        [  0.87156488,  -8.85640194],
#        [ -0.16279462,  -7.16755512],
#        [ -0.66815499,  -1.41864677],
#        [  0.46421771,  -5.0659824 ],
#        [  1.4345815 ,  -3.40408299],
#        [ -0.5428427 ,  -8.17241359],
#        [  0.58133467,   4.71198527],
#        [  1.84204735,  -1.24494874],
#        [ -0.47589396,   1.81362086],
#        [  2.07055701,  -6.78263537],
#        [  0.92939395,  -2.36089066],
#        [  0.86406875,   2.72478535],
#        [  2.0395428 ,   4.65232662],
#        [  2.08037137,   2.63446694],
#        [ -0.6976181 ,  -3.13192566],
#        [  1.17395054,  -5.05092407],
#        [  1.40915279,  -6.88212   ],
#        [  1.90398101,  -8.58210347],
#        [  1.34909422,  -1.68754152],
#        [  1.04573645,  -9.91170811],
#        [  0.66097686,   0.42402516],
#        [ -0.33518859,   3.11941077],
#        [  0.13197551,  -5.80786978],
#        [  1.02849429,   6.56682707],
#        [  1.22353837,   6.90661019],
#        [  2.83261667,  -2.24063726],
#        [  1.06542349,  -0.79286861],
#        [  0.98674012,   1.0012648 ],
#        [ -0.32627811,  -6.43329217],
#        [  1.62924878,  -7.10738083],
#        [  1.05015446,  -4.34313473],
#        [  2.69165923,  -2.41636632],
#        [  1.04067587,  -6.31027042],
#        [  1.43088069,  -4.26655897],
#        [ -0.32902968,   1.48837865],
#        [  0.59743951, -10.7722967 ],
#        [ -0.16121213,  -4.95940734],
#        [  0.93120728,  -0.3780837 ],
#        [  1.14140748,   1.08732121],
#        [  1.14322134,   0.13748682],
#        [  0.02201105,   2.07102129],
#        [  1.32832113,  -4.33681365],
#        [  0.82370788,  -4.8420447 ],
#        [  1.82383639,   1.45837422],
#        [  0.50944722,   4.63117272],
#        [  1.24823015,   0.26331632],
#        [  0.83078701,   4.70047522],
#        [  0.18548062,  -6.61376724],
#        [  1.35957589,   1.9716294 ],
#        [  1.2743679 ,  -4.95706384],
#        [  0.87872344,  -1.07830609],
#        [  0.3426436 ,  -3.07569439],
#        [  1.97764284,  -6.38629878],
#        [  1.48479716,  -2.14503109],
#        [  1.8644062 ,  -7.30709179],
#        [  1.01628399,  -6.75501372],
#        [  0.39105028,   3.77425608],
#        [ -0.39601869,  -4.96916569],
#        [ -0.04918344,  -4.99800136],
#        [  1.44001343,  -1.48637528],
#        [  1.7266388 ,   0.20485943],
#        [  0.49060616,   5.27771345],
#        [  1.21869979,  -2.08390772],
#        [  2.16025578,  -0.66625859],
#        [  1.60625475,   0.59343319],
#        [  2.14819678,  -2.00122982],
#        [  1.26324793,  -1.59665906],
#        [  1.56276021,  -4.45542892],
#        [  1.95549893,   2.43145589],
#        [  1.54639286,  -8.81579963],
#        [  0.84619616,   0.94401416],
#        [ -1.31655321,   0.58837043],
#        [  1.36850778,   5.82139523],
#        [  1.09569812,  -3.91139261],
#        [  0.46491916,   1.44384521],
#        [  1.69993084,   1.19703592],
#        [  1.33149083,  -3.43807829],
#        [ -0.89603202,  -2.92809167],
#        [  0.29529355,  -1.66229588],
#        [  2.31128669,  -1.72468195],
#        [  0.33290133,  -4.06649629],
#        [  1.92590849,   0.62938555],
#        [ -0.39882107,  -4.23071985],
#        [ -2.1384399 ,  -1.71258648],
#        [  0.94343301,   2.77133924],
#        [ -0.44758654,   0.49444917],
#        [  2.68415794,  -2.9711176 ],
#        [  1.34821217,  -0.49389289],
#        [  0.47588536,   1.01869399],
#        [  0.59167029,   1.76962119],
#        [ -0.14293079,  -8.27978304],
#        [  1.88144015,  -8.36191432],
#        [  2.57804691,   0.86873262],
#        [  0.95235171,  -5.67747662],
#        [ -1.70679821,   3.13309092],
#        [  1.47566369,  -3.67534401],
#        [ -0.59973271,  -4.75745406],
#        [  0.43913261,  -1.20365957],
#        [  0.60764508,  -7.75227071]])

# %%
type(X)
# Out:
# numpy.ndarray

# %%
df3 = pd.DataFrame(X, columns=['x1','x2'])
df3
# Out:
#           x1        x2
# 0   1.139314  2.009211
# 1   0.871565 -8.856402
# 2  -0.162795 -7.167555
# 3  -0.668155 -1.418647
# 4   0.464218 -5.065982
# 5   1.434582 -3.404083
# 6  -0.542843 -8.172414
# 7   0.581335  4.711985
# 8   1.842047 -1.244949
# 9  -0.475894  1.813621
# 10  2.070557 -6.782635
# 11  0.929394 -2.360891
# 12  0.864069  2.724785
# 13  2.039543  4.652327
# 14  2.080371  2.634467
# 15 -0.697618 -3.131926
# 16  1.173951 -5.050924
# 17  1.409153 -6.882120
# 18  1.903981 -8.582103
# 19  1.349094 -1.687542
# 20  1.045736 -9.911708
# 21  0.660977  0.424025
# 22 -0.335189  3.119411
# 23  0.131976 -5.807870
# 24  1.028494  6.566827
# 25  1.223538  6.906610
# 26  2.832617 -2.240637
# 27  1.065423 -0.792869
# 28  0.986740  1.001265
# 29 -0.326278 -6.433292
# ..       ...       ...
# 70  1.546393 -8.815800
# 71  0.846196  0.944014
# 72 -1.316553  0.588370
# 73  1.368508  5.821395
# 74  1.095698 -3.911393
# 75  0.464919  1.443845
# 76  1.699931  1.197036
# 77  1.331491 -3.438078
# 78 -0.896032 -2.928092
# 79  0.295294 -1.662296
# 80  2.311287 -1.724682
# 81  0.332901 -4.066496
# 82  1.925908  0.629386
# 83 -0.398821 -4.230720
# 84 -2.138440 -1.712586
# 85  0.943433  2.771339
# 86 -0.447587  0.494449
# 87  2.684158 -2.971118
# 88  1.348212 -0.493893
# 89  0.475885  1.018694
# 90  0.591670  1.769621
# 91 -0.142931 -8.279783
# 92  1.881440 -8.361914
# 93  2.578047  0.868733
# 94  0.952352 -5.677477
# 95 -1.706798  3.133091
# 96  1.475664 -3.675344
# 97 -0.599733 -4.757454
# 98  0.439133 -1.203660
# 99  0.607645 -7.752271
#
# [100 rows x 2 columns]

# %%
plt.scatter(df3['x1'], df3['x2'])
# Out:
# <img src="data:image/png;base64,..." width="432">
